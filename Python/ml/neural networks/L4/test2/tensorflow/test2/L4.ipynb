# %%
from google.colab import files
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !cp /content/drive/MyDrive/Colab\ Notebooks/L4/main.py /content/drive/MyDrive/Colab\ Notebooks/L4/working_directory
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab Notebooks/L4')
import main
# %run main.py
# Out:
# Mounted at /content/drive
# ----------AlexNet TENSORFLOW convolutional neural network----------
# Removing the folder  Animals10_train... Done.
# Removing the folder  Animals10_test... Done.
# Preparing dataset and model...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Found 20938 images belonging to 10 classes.
# Found 5241 images belonging to 10 classes.
# Time of data preparations:  0 : 4 : 31
# ...
